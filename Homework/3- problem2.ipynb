# %%
employees = [{
            "name": "Ronda Swanson",
            "age": 55,
            "department": "Management",
            "phone": "555-1234",
            "salary": "15,000"},
    {
            "name": "Tina Turner",
            "age": 25,
            "department": "Accounting",
            "phone": "555-4254",
            "salary": "45,000"},
    {
            "name": "Gloria Esteban",
            "age": 64,
            "department": "Sales",
            "phone": "555-1223",
            "salary": "23,000"},
    {
            "name": "Whitney Houston",
            "age": 55,
            "department": "Operations",
            "phone": "555-1284",
            "salary": "52,000"},
    {
            "name": "Selina Gomez Swanson",
            "age": 55,
            "department": "Marketing",
            "phone": "555-2134",
            "salary": "67,000"}]

# %%
for person in employees:
    print(f'{person["name"]} in {person["department"]} can be reached at {person["phone"]}')
# Out:
# Ronda Swanson in Management can be reached at 555-1234
# Tina Turner in Accounting can be reached at 555-4254
# Gloria Esteban in Sales can be reached at 555-1223
# Whitney Houston in Operations can be reached at 555-1284
# Selina Gomez Swanson in Marketing can be reached at 555-2134
