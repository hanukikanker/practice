# %%
# From pseudocode
angry = False
bored = True
hungry = True
tired = True

if angry and hungry and bored:
    print("Eats triceratops")
elif tired and hungry:
    print("Eats Iguanadon")
elif hungry and bored:
    print("Eats Stegasaurus")
elif tired:
    print("Sleeps")
elif angry and bored:
    print("Fights Velociraptor")
elif angry or bored:
    print("Roars")
else:
    print("Smiles") 
    
# Is there a more elegant way to write this?
# Out:
# Eats Iguanadon
